# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataframe = pd.read_csv('/home/dieudonne/SPECIALIZATION/Data Analytics/world-population.csv')
dataframe.head()
# Out:
#    Rank CCA3 Country/Territory           Capital Continent  2022 Population  \
# 0    36  AFG       Afghanistan             Kabul      Asia         41128771
# 1   138  ALB           Albania            Tirana    Europe          2842321
# 2    34  DZA           Algeria           Algiers    Africa         44903225
# 3   213  ASM    American Samoa         Pago Pago   Oceania            44273
# 4   203  AND           Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %% [markdown]
# ### How to manipulate floats or numbers after the comma. You can for example want to have something like x.0 or x.00 or x.000.
# #### You can tell Pandas to select only columns that are already "numbers" (integers or other floats) and convert them all to float64. This completely avoids your text columns.

# %%
numeric_cols = dataframe.select_dtypes(include=['number']).columns
dataframe[numeric_cols] = dataframe[numeric_cols].astype(float)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
dataframe
# Out:
#       Rank CCA3  Country/Territory           Capital Continent  \
# 0    36.00  AFG        Afghanistan             Kabul      Asia
# 1   138.00  ALB            Albania            Tirana    Europe
# 2    34.00  DZA            Algeria           Algiers    Africa
# 3   213.00  ASM     American Samoa         Pago Pago   Oceania
# 4   203.00  AND            Andorra  Andorra la Vella    Europe
# ..     ...  ...                ...               ...       ...
# 229 226.00  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230 172.00  ESH     Western Sahara          El Aaiún    Africa
# 231  46.00  YEM              Yemen             Sanaa      Asia
# 232  63.00  ZMB             Zambia            Lusaka    Africa
# 233  74.00  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0        41128771.00      38972230.00      33753499.00      28189672.00
# ...

# %% [markdown]
# ### When you want to get the high level information about the data

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    float64
#  1   CCA3                         234 non-null    object
#  2   Country/Territory            234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    float64
#  6   2020 Population              234 non-null    float64
#  7   2015 Population              234 non-null    float64
#  8   2010 Population              234 non-null    float64
#  9   2000 Population              234 non-null    float64
#  10  1990 Population              234 non-null    float64
#  11  1980 Population              234 non-null    float64
# ...

# %% [markdown]
# ### Whe you want to get the high overview of the dataset, you can use .describe

# %%
dataframe.describe()
# Out:
#         Rank  2022 Population  2020 Population  2015 Population  \
# count 234.00           234.00           234.00           234.00
# mean  117.50      34074414.71      33501070.95      31729956.24
# std    67.69     136766424.80     135589876.92     130404992.75
# min     1.00           510.00           520.00           564.00
# 25%    59.25        419738.50        415284.50        404676.00
# 50%   117.50       5559944.50       5493074.50       5307400.00
# 75%   175.75      22476504.75      21447979.50      19730853.75
# max   234.00    1425887337.00    1424929781.00    1393715448.00
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count           234.00           234.00           234.00           234.00
# mean       29845235.03      26269468.82      22710220.79      18984616.97
# std       124218487.63     111698206.72      97832173.35      81785186.08
# min             596.00           651.00           700.00           733.00
# ...
